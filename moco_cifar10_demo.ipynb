# %% [markdown]
# <a href="https://colab.research.google.com/github/zzp-seeker/VM_web/blob/master/moco_cifar10_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MoCo Demo: CIFAR-10
#
# This is a simple demo for training MoCo on CIFAR-10. It can be run directly in a Colab notebook using a publicly available GPU.
#
# #### Results
#
# These are the ResNet-18 classification accuracy of a **kNN monitor** on the unsupervised pre-training features.
#
# | config | 200ep | 400ep | 800ep |
# | --- | --- | --- | --- |
# | Asymmetric | 82.6 | 86.3 | 88.7 |
# | Symmetric | 85.3 | 88.5 | 89.7 |
#
# #### Notes
#
# * **Symmetric loss**: the original MoCo paper uses an *asymmetric* loss -- one crop is the query and the other crop is the key, and it backpropagates to one crop (query). Following SimCLR/BYOL, here we provide an option of a *symmetric* loss -- it swaps the two crops and computes an extra loss. The symmetric loss behaves like 2x epochs of the asymmetric counterpart: this may dominate the comparison results when the models are trained with a fixed epoch number.
#
# * **SplitBatchNorm**: the original MoCo was trained in 8 GPUs. To simulate the multi-GPU behavior of BatchNorm in this 1-GPU demo, we provide a SplitBatchNorm layer. We set `--bn-splits 8` by default to simulate 8 GPUs. `--bn-splits 1` is analogous to SyncBatchNorm in the multi-GPU case.
#
# * **kNN monitor**: this demo provides a kNN monitor on the test set. Training a linear classifier on frozen features often achieves higher accuracy. To train a linear classifier (not provided in this demo), we recommend using lr=30, wd=0, epochs=100 with a stepwise or cosine schedule. The ResNet-18 model (kNN 89.7) has 90.7 linear classification accuracy.
#
# #### Disclaimer
#
# This demo aims to provide an interface with a free GPU (thanks to Colab) for understanding how the code runs. We suggest users be careful to draw conclusions from CIFAR, which may not generalize beyond this dataset. We have verified that it is beneficial to have the momentum encoder (disabling it by `--moco-m 0.0` should fail), queue size (saturated at `--moco-k 4096`) and ShuffleBN (without which loses 4% at 800 epochs) on CIFAR, similar to the observations on ImageNet. But new observations made only on CIFAR should be judged with caution.
#
# #### References
# This demo is adapted from:
# * http://github.com/zhirongw/lemniscate.pytorch
# * https://github.com/leftthomas/SimCLR

# %% [markdown]
# ### Prepare
#
# Check GPU settings. A free GPU in Colab is <= Tesla P100. The log of the demo is based on a Tesla V100 from Google Cloud Platform.

# %%
gpu_info = !nvidia-smi -i 0
gpu_info = '\n'.join(gpu_info)
print(gpu_info)

from datetime import datetime
from functools import partial
from PIL import Image
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CIFAR10
from torchvision.models import resnet
from tqdm import tqdm
import argparse
import json
import math
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
# Out:
# Wed Nov 18 10:21:53 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    25W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Set arguments

# %%
parser = argparse.ArgumentParser(description='Train MoCo on CIFAR-10')

parser.add_argument('-a', '--arch', default='resnet18')

# lr: 0.06 for batch 512 (or 0.03 for batch 256)
parser.add_argument('--lr', '--learning-rate', default=0.06, type=float, metavar='LR', help='initial learning rate', dest='lr')
parser.add_argument('--epochs', default=200, type=int, metavar='N', help='number of total epochs to run')
parser.add_argument('--schedule', default=[120, 160], nargs='*', type=int, help='learning rate schedule (when to drop lr by 10x); does not take effect if --cos is on')
parser.add_argument('--cos', action='store_true', help='use cosine lr schedule')

parser.add_argument('--batch-size', default=512, type=int, metavar='N', help='mini-batch size')
parser.add_argument('--wd', default=5e-4, type=float, metavar='W', help='weight decay')

# moco specific configs:
parser.add_argument('--moco-dim', default=128, type=int, help='feature dimension')
parser.add_argument('--moco-k', default=4096, type=int, help='queue size; number of negative keys')
parser.add_argument('--moco-m', default=0.99, type=float, help='moco momentum of updating key encoder')
parser.add_argument('--moco-t', default=0.1, type=float, help='softmax temperature')

parser.add_argument('--bn-splits', default=8, type=int, help='simulate multi-gpu behavior of BatchNorm in one gpu; 1 is SyncBatchNorm in multi-gpu')

parser.add_argument('--symmetric', action='store_true', help='use a symmetric loss function that backprops to both crops')

# knn monitor
parser.add_argument('--knn-k', default=200, type=int, help='k in kNN monitor')
parser.add_argument('--knn-t', default=0.1, type=float, help='softmax temperature in kNN monitor; could be different with moco-t')

# utils
parser.add_argument('--resume', default='', type=str, metavar='PATH', help='path to latest checkpoint (default: none)')
parser.add_argument('--results-dir', default='', type=str, metavar='PATH', help='path to cache (default: none)')

'''
args = parser.parse_args()  # running in command line
'''
args = parser.parse_args('')  # running in ipynb

# set command line arguments here when running in ipynb
args.epochs = 200
args.cos = True
args.schedule = []  # cos in use
args.symmetric = False
if args.results_dir == '':
    args.results_dir = './cache-' + datetime.now().strftime("%Y-%m-%d-%H-%M-%S-moco")

print(args)
# Out:
# Namespace(arch='resnet18', batch_size=512, bn_splits=8, cos=True, epochs=200, knn_k=200, knn_t=0.1, lr=0.06, moco_dim=128, moco_k=4096, moco_m=0.99, moco_t=0.1, results_dir='./cache-2020-11-18-10-21-55-moco', resume='', schedule=[], symmetric=False, wd=0.0005)

# %% [markdown]
# ### Define data loaders

# %%
class CIFAR10Pair(CIFAR10):
    """CIFAR10 Dataset.
    """
    def __getitem__(self, index):
        img = self.data[index]
        img = Image.fromarray(img)

        if self.transform is not None:
            im_1 = self.transform(img)
            im_2 = self.transform(img)

        return im_1, im_2

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(32),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
    transforms.RandomGrayscale(p=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])])

# data prepare
train_data = CIFAR10Pair(root='data', train=True, transform=train_transform, download=True)
train_loader = DataLoader(train_data, batch_size=args.batch_size, shuffle=True, num_workers=16, pin_memory=True, drop_last=True)

memory_data = CIFAR10(root='data', train=True, transform=test_transform, download=True)
memory_loader = DataLoader(memory_data, batch_size=args.batch_size, shuffle=False, num_workers=16, pin_memory=True)

test_data = CIFAR10(root='data', train=False, transform=test_transform, download=True)
test_loader = DataLoader(test_data, batch_size=args.batch_size, shuffle=False, num_workers=16, pin_memory=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Define base encoder

# %%
# SplitBatchNorm: simulate multi-gpu behavior of BatchNorm in one gpu by splitting alone the batch dimension
# implementation adapted from https://github.com/davidcpage/cifar10-fast/blob/master/torch_backend.py
class SplitBatchNorm(nn.BatchNorm2d):
    def __init__(self, num_features, num_splits, **kw):
        super().__init__(num_features, **kw)
        self.num_splits = num_splits
        
    def forward(self, input):
        N, C, H, W = input.shape
        if self.training or not self.track_running_stats:
            running_mean_split = self.running_mean.repeat(self.num_splits)
            running_var_split = self.running_var.repeat(self.num_splits)
            outcome = nn.functional.batch_norm(
                input.view(-1, C * self.num_splits, H, W), running_mean_split, running_var_split, 
                self.weight.repeat(self.num_splits), self.bias.repeat(self.num_splits),
                True, self.momentum, self.eps).view(N, C, H, W)
            self.running_mean.data.copy_(running_mean_split.view(self.num_splits, C).mean(dim=0))
            self.running_var.data.copy_(running_var_split.view(self.num_splits, C).mean(dim=0))
            return outcome
        else:
            return nn.functional.batch_norm(
                input, self.running_mean, self.running_var, 
                self.weight, self.bias, False, self.momentum, self.eps)

class ModelBase(nn.Module):
    """
    Common CIFAR ResNet recipe.
    Comparing with ImageNet ResNet recipe, it:
    (i) replaces conv1 with kernel=3, str=1
    (ii) removes pool1
    """
    def __init__(self, feature_dim=128, arch=None, bn_splits=16):
        super(ModelBase, self).__init__()

        # use split batchnorm
        norm_layer = partial(SplitBatchNorm, num_splits=bn_splits) if bn_splits > 1 else nn.BatchNorm2d
        resnet_arch = getattr(resnet, arch)
        net = resnet_arch(num_classes=feature_dim, norm_layer=norm_layer)

        self.net = []
        for name, module in net.named_children():
            if name == 'conv1':
                module = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
            if isinstance(module, nn.MaxPool2d):
                continue
            if isinstance(module, nn.Linear):
                self.net.append(nn.Flatten(1))
            self.net.append(module)

        self.net = nn.Sequential(*self.net)

    def forward(self, x):
        x = self.net(x)
        # note: not normalized here
        return x

# %% [markdown]
# ### Define MoCo wrapper

# %%
class ModelMoCo(nn.Module):
    def __init__(self, dim=128, K=4096, m=0.99, T=0.1, arch='resnet18', bn_splits=8, symmetric=True):
        super(ModelMoCo, self).__init__()

        self.K = K
        self.m = m
        self.T = T
        self.symmetric = symmetric

        # create the encoders
        self.encoder_q = ModelBase(feature_dim=dim, arch=arch, bn_splits=bn_splits)
        self.encoder_k = ModelBase(feature_dim=dim, arch=arch, bn_splits=bn_splits)

        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)  # initialize
            param_k.requires_grad = False  # not update by gradient

        # create the queue
        self.register_buffer("queue", torch.randn(dim, K))
        self.queue = nn.functional.normalize(self.queue, dim=0)

        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        """
        Momentum update of the key encoder
        """
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1. - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        batch_size = keys.shape[0]

        ptr = int(self.queue_ptr)
        assert self.K % batch_size == 0  # for simplicity

        # replace the keys at ptr (dequeue and enqueue)
        self.queue[:, ptr:ptr + batch_size] = keys.t()  # transpose
        ptr = (ptr + batch_size) % self.K  # move pointer

        self.queue_ptr[0] = ptr

    @torch.no_grad()
    def _batch_shuffle_single_gpu(self, x):
        """
        Batch shuffle, for making use of BatchNorm.
        """
        # random shuffle index
        idx_shuffle = torch.randperm(x.shape[0]).cuda()

        # index for restoring
        idx_unshuffle = torch.argsort(idx_shuffle)

        return x[idx_shuffle], idx_unshuffle

    @torch.no_grad()
    def _batch_unshuffle_single_gpu(self, x, idx_unshuffle):
        """
        Undo batch shuffle.
        """
        return x[idx_unshuffle]

    def contrastive_loss(self, im_q, im_k):
        # compute query features
        q = self.encoder_q(im_q)  # queries: NxC
        q = nn.functional.normalize(q, dim=1)  # already normalized

        # compute key features
        with torch.no_grad():  # no gradient to keys
            # shuffle for making use of BN
            im_k_, idx_unshuffle = self._batch_shuffle_single_gpu(im_k)

            k = self.encoder_k(im_k_)  # keys: NxC
            k = nn.functional.normalize(k, dim=1)  # already normalized

            # undo shuffle
            k = self._batch_unshuffle_single_gpu(k, idx_unshuffle)

        # compute logits
        # Einstein sum is more intuitive
        # positive logits: Nx1
        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
        # negative logits: NxK
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach()])

        # logits: Nx(1+K)
        logits = torch.cat([l_pos, l_neg], dim=1)

        # apply temperature
        logits /= self.T

        # labels: positive key indicators
        labels = torch.zeros(logits.shape[0], dtype=torch.long).cuda()
        
        loss = nn.CrossEntropyLoss().cuda()(logits, labels)

        return loss, q, k

    def forward(self, im1, im2):
        """
        Input:
            im_q: a batch of query images
            im_k: a batch of key images
        Output:
            loss
        """

        # update the key encoder
        with torch.no_grad():  # no gradient to keys
            self._momentum_update_key_encoder()

        # compute loss
        if self.symmetric:  # asymmetric loss
            loss_12, q1, k2 = self.contrastive_loss(im1, im2)
            loss_21, q2, k1 = self.contrastive_loss(im2, im1)
            loss = loss_12 + loss_21
            k = torch.cat([k1, k2], dim=0)
        else:  # asymmetric loss
            loss, q, k = self.contrastive_loss(im1, im2)

        self._dequeue_and_enqueue(k)

        return loss

# create model
model = ModelMoCo(
        dim=args.moco_dim,
        K=args.moco_k,
        m=args.moco_m,
        T=args.moco_t,
        arch=args.arch,
        bn_splits=args.bn_splits,
        symmetric=args.symmetric,
    ).cuda()
print(model.encoder_q)
# Out:
# ModelBase(
#   (net): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): SplitBatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): AdaptiveAvgPool2d(output_size=(1, 1))
#     (8): Flatten(start_dim=1, end_dim=-1)
#     (9): Linear(in_features=512, out_features=128, bias=True)
#   )
# )

# %% [markdown]
# ### Define train/test

# %%
# train for one epoch
def train(net, data_loader, train_optimizer, epoch, args):
    net.train()
    adjust_learning_rate(optimizer, epoch, args)

    # total_loss, total_num, train_bar = 0.0, 0, tqdm(data_loader)
    total_loss, total_num = 0.0, 0
    # for im_1, im_2 in train_bar:
    for t,(im_1,im_2) in enumerate(data_loader):
        im_1, im_2 = im_1.cuda(non_blocking=True), im_2.cuda(non_blocking=True)

        loss = net(im_1, im_2)
        
        train_optimizer.zero_grad()
        loss.backward()
        train_optimizer.step()

        total_num += data_loader.batch_size
        total_loss += loss.item() * data_loader.batch_size
        # train_bar.set_description('Train Epoch: [{}/{}], lr: {:.6f}, Loss: {:.4f}'.format(epoch, args.epochs, optimizer.param_groups[0]['lr'], total_loss / total_num))
    print('Train Epoch: [{}/{}], lr: {:.6f}, Loss: {:.4f}'.format(epoch, args.epochs, optimizer.param_groups[0]['lr'], total_loss / total_num))

    return total_loss / total_num

# lr scheduler for training
def adjust_learning_rate(optimizer, epoch, args):
    """Decay the learning rate based on schedule"""
    lr = args.lr
    if args.cos:  # cosine lr schedule
        lr *= 0.5 * (1. + math.cos(math.pi * epoch / args.epochs))
    else:  # stepwise lr schedule
        for milestone in args.schedule:
            lr *= 0.1 if epoch >= milestone else 1.
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
# test using a knn monitor
def test(net, memory_data_loader, test_data_loader, epoch, args):
    net.eval()
    classes = len(memory_data_loader.dataset.classes)
    total_top1, total_top5, total_num, feature_bank = 0.0, 0.0, 0, []
    with torch.no_grad():
        # generate feature bank
        # for data, target in tqdm(memory_data_loader, desc='Feature extracting'):
        for t,(data, target) in enumerate(memory_data_loader):
            feature = net(data.cuda(non_blocking=True))
            feature = F.normalize(feature, dim=1)
            feature_bank.append(feature)
        # [D, N]
        feature_bank = torch.cat(feature_bank, dim=0).t().contiguous()
        # [N]
        feature_labels = torch.tensor(memory_data_loader.dataset.targets, device=feature_bank.device)
        # loop test data to predict the label by weighted knn search
        # test_bar = tqdm(test_data_loader)
        # for data, target in test_bar:
        for t,(data,target) in enumerate(test_data_loader):
            data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            feature = net(data)
            feature = F.normalize(feature, dim=1)
            
            pred_labels = knn_predict(feature, feature_bank, feature_labels, classes, args.knn_k, args.knn_t)

            total_num += data.size(0)
            total_top1 += (pred_labels[:, 0] == target).float().sum().item()
            # test_bar.set_description('Test Epoch: [{}/{}] Acc@1:{:.2f}%'.format(epoch, args.epochs, total_top1 / total_num * 100))
        print('Test Epoch: [{}/{}] total_top1:{} total_num:{} Acc@1:{:.2f}%'.format(epoch, args.epochs, total_top1, total_num, total_top1 / total_num * 100))   

    return total_top1 / total_num * 100

# knn monitor as in InstDisc https://arxiv.org/abs/1805.01978
# implementation follows http://github.com/zhirongw/lemniscate.pytorch and https://github.com/leftthomas/SimCLR
def knn_predict(feature, feature_bank, feature_labels, classes, knn_k, knn_t):
    # compute cos similarity between each feature vector and feature bank ---> [B, N]
    sim_matrix = torch.mm(feature, feature_bank)
    # [B, K]
    sim_weight, sim_indices = sim_matrix.topk(k=knn_k, dim=-1)
    # [B, K]
    sim_labels = torch.gather(feature_labels.expand(feature.size(0), -1), dim=-1, index=sim_indices)
    sim_weight = (sim_weight / knn_t).exp()

    # counts for each class
    one_hot_label = torch.zeros(feature.size(0) * knn_k, classes, device=sim_labels.device)
    # [B*K, C]
    one_hot_label = one_hot_label.scatter(dim=-1, index=sim_labels.view(-1, 1), value=1.0)
    # weighted score ---> [B, C]
    pred_scores = torch.sum(one_hot_label.view(feature.size(0), -1, classes) * sim_weight.unsqueeze(dim=-1), dim=1)

    pred_labels = pred_scores.argsort(dim=-1, descending=True)
    return pred_labels

# %% [markdown]
# ### Start training

# %%
# define optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, weight_decay=args.wd, momentum=0.9)

# load model if resume
epoch_start = 1
if args.resume is not '':
    checkpoint = torch.load(args.resume)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    epoch_start = checkpoint['epoch'] + 1
    print('Loaded from: {}'.format(args.resume))

# logging
results = {'train_loss': [], 'test_acc@1': []}
if not os.path.exists(args.results_dir):
    os.mkdir(args.results_dir)
# dump args
with open(args.results_dir + '/args.json', 'w') as fid:
    json.dump(args.__dict__, fid, indent=2)

# training loop
for epoch in range(epoch_start, args.epochs + 1):
    train_loss = train(model, train_loader, optimizer, epoch, args)
    results['train_loss'].append(train_loss)
    test_acc_1 = test(model.encoder_q, memory_loader, test_loader, epoch, args)
    results['test_acc@1'].append(test_acc_1)
    # save statistics
    data_frame = pd.DataFrame(data=results, index=range(epoch_start, epoch + 1))
    data_frame.to_csv(args.results_dir + '/log.csv', index_label='epoch')
    # save model
    torch.save({'epoch': epoch, 'state_dict': model.state_dict(), 'optimizer' : optimizer.state_dict(),}, args.results_dir + '/model_last.pth')
# Out:
# Train Epoch: [1/200], lr: 0.059996, Loss: 6.7507
# Test Epoch: [1/200] total_top1:3248.0 total_num:10000 Acc@1:32.48%
# Train Epoch: [2/200], lr: 0.059985, Loss: 7.0014
# Test Epoch: [2/200] total_top1:3495.0 total_num:10000 Acc@1:34.95%
# Train Epoch: [3/200], lr: 0.059967, Loss: 6.9733
# Test Epoch: [3/200] total_top1:3672.0 total_num:10000 Acc@1:36.72%
# Train Epoch: [4/200], lr: 0.059941, Loss: 6.8224
# Test Epoch: [4/200] total_top1:3922.0 total_num:10000 Acc@1:39.22%
# Train Epoch: [5/200], lr: 0.059908, Loss: 6.6569
# Test Epoch: [5/200] total_top1:3945.0 total_num:10000 Acc@1:39.45%
# Train Epoch: [6/200], lr: 0.059867, Loss: 6.5469
# Test Epoch: [6/200] total_top1:4256.0 total_num:10000 Acc@1:42.56%
# Train Epoch: [7/200], lr: 0.059819, Loss: 6.3638
# Test Epoch: [7/200] total_top1:4455.0 total_num:10000 Acc@1:44.55%
# Train Epoch: [8/200], lr: 0.059763, Loss: 6.1488
# Test Epoch: [8/200] total_top1:4646.0 total_num:10000 Acc@1:46.46%
# Train Epoch: [9/200], lr: 0.059701, Loss: 5.9640
# Test Epoch: [9/200] total_top1:4874.0 total_num:10000 Acc@1:48.74%
# Train Epoch: [10/200], lr: 0.059631, Loss: 5.7101
# Test Epoch: [10/200] total_top1:5048.0 total_num:10000 Acc@1:50.48%
# Train Epoch: [11/200], lr: 0.059553, Loss: 5.5165
# Test Epoch: [11/200] total_top1:5151.0 total_num:10000 Acc@1:51.51%
# Train Epoch: [12/200], lr: 0.059469, Loss: 5.3263
# Test Epoch: [12/200] total_top1:5313.0 total_num:10000 Acc@1:53.13%
# Train Epoch: [13/200], lr: 0.059377, Loss: 5.1730
# Test Epoch: [13/200] total_top1:5482.0 total_num:10000 Acc@1:54.82%
# Train Epoch: [14/200], lr: 0.059278, Loss: 5.0023
# Test Epoch: [14/200] total_top1:5602.0 total_num:10000 Acc@1:56.02%
# Train Epoch: [15/200], lr: 0.059171, Loss: 4.8570
# Test Epoch: [15/200] total_top1:5718.0 total_num:10000 Acc@1:57.18%
# Train Epoch: [16/200], lr: 0.059057, Loss: 4.7063
# Test Epoch: [16/200] total_top1:5802.0 total_num:10000 Acc@1:58.02%
# Train Epoch: [17/200], lr: 0.058937, Loss: 4.6092
# Test Epoch: [17/200] total_top1:5968.0 total_num:10000 Acc@1:59.68%
# Train Epoch: [18/200], lr: 0.058809, Loss: 4.5042
# Test Epoch: [18/200] total_top1:6036.0 total_num:10000 Acc@1:60.36%
# Train Epoch: [19/200], lr: 0.058674, Loss: 4.3960
# Test Epoch: [19/200] total_top1:6140.0 total_num:10000 Acc@1:61.40%
# Train Epoch: [20/200], lr: 0.058532, Loss: 4.2859
# Test Epoch: [20/200] total_top1:6254.0 total_num:10000 Acc@1:62.54%
# Train Epoch: [21/200], lr: 0.058383, Loss: 4.2028
# Test Epoch: [21/200] total_top1:6294.0 total_num:10000 Acc@1:62.94%
# Train Epoch: [22/200], lr: 0.058226, Loss: 4.1356
# Test Epoch: [22/200] total_top1:6422.0 total_num:10000 Acc@1:64.22%
# Train Epoch: [23/200], lr: 0.058063, Loss: 4.0535
# Test Epoch: [23/200] total_top1:6525.0 total_num:10000 Acc@1:65.25%
# Train Epoch: [24/200], lr: 0.057893, Loss: 3.9824
# Test Epoch: [24/200] total_top1:6488.0 total_num:10000 Acc@1:64.88%
# Train Epoch: [25/200], lr: 0.057716, Loss: 3.9357
# Test Epoch: [25/200] total_top1:6657.0 total_num:10000 Acc@1:66.57%
# Train Epoch: [26/200], lr: 0.057533, Loss: 3.8764
# Test Epoch: [26/200] total_top1:6693.0 total_num:10000 Acc@1:66.93%
# Train Epoch: [27/200], lr: 0.057342, Loss: 3.8238
# Test Epoch: [27/200] total_top1:6681.0 total_num:10000 Acc@1:66.81%
# Train Epoch: [28/200], lr: 0.057145, Loss: 3.7693
# Test Epoch: [28/200] total_top1:6803.0 total_num:10000 Acc@1:68.03%
# Train Epoch: [29/200], lr: 0.056941, Loss: 3.7077
# Test Epoch: [29/200] total_top1:6716.0 total_num:10000 Acc@1:67.16%
# Train Epoch: [30/200], lr: 0.056730, Loss: 3.6941
# Test Epoch: [30/200] total_top1:6860.0 total_num:10000 Acc@1:68.60%
# Train Epoch: [31/200], lr: 0.056513, Loss: 3.6377
# Test Epoch: [31/200] total_top1:6832.0 total_num:10000 Acc@1:68.32%
# Train Epoch: [32/200], lr: 0.056289, Loss: 3.6188
# Test Epoch: [32/200] total_top1:6885.0 total_num:10000 Acc@1:68.85%
# Train Epoch: [33/200], lr: 0.056059, Loss: 3.5842
# Test Epoch: [33/200] total_top1:6875.0 total_num:10000 Acc@1:68.75%
# Train Epoch: [34/200], lr: 0.055822, Loss: 3.5482
# Test Epoch: [34/200] total_top1:7008.0 total_num:10000 Acc@1:70.08%
# Train Epoch: [35/200], lr: 0.055579, Loss: 3.5176
# Test Epoch: [35/200] total_top1:6975.0 total_num:10000 Acc@1:69.75%
# Train Epoch: [36/200], lr: 0.055330, Loss: 3.4661
# Test Epoch: [36/200] total_top1:7024.0 total_num:10000 Acc@1:70.24%
# Train Epoch: [37/200], lr: 0.055074, Loss: 3.4642
# Test Epoch: [37/200] total_top1:7013.0 total_num:10000 Acc@1:70.13%
# Train Epoch: [38/200], lr: 0.054812, Loss: 3.4369
# Test Epoch: [38/200] total_top1:7016.0 total_num:10000 Acc@1:70.16%
# Train Epoch: [39/200], lr: 0.054544, Loss: 3.4160
# Test Epoch: [39/200] total_top1:7089.0 total_num:10000 Acc@1:70.89%
# Train Epoch: [40/200], lr: 0.054271, Loss: 3.4003
# Test Epoch: [40/200] total_top1:7111.0 total_num:10000 Acc@1:71.11%
# Train Epoch: [41/200], lr: 0.053991, Loss: 3.3757
# Test Epoch: [41/200] total_top1:7158.0 total_num:10000 Acc@1:71.58%
# Train Epoch: [42/200], lr: 0.053705, Loss: 3.3642
# Test Epoch: [42/200] total_top1:7163.0 total_num:10000 Acc@1:71.63%
# Train Epoch: [43/200], lr: 0.053413, Loss: 3.3363
# Test Epoch: [43/200] total_top1:7205.0 total_num:10000 Acc@1:72.05%
# Train Epoch: [44/200], lr: 0.053115, Loss: 3.3044
# Test Epoch: [44/200] total_top1:7244.0 total_num:10000 Acc@1:72.44%
# Train Epoch: [45/200], lr: 0.052812, Loss: 3.2812
# Test Epoch: [45/200] total_top1:7282.0 total_num:10000 Acc@1:72.82%
# Train Epoch: [46/200], lr: 0.052503, Loss: 3.2619
# Test Epoch: [46/200] total_top1:7187.0 total_num:10000 Acc@1:71.87%
# Train Epoch: [47/200], lr: 0.052189, Loss: 3.2535
# Test Epoch: [47/200] total_top1:7248.0 total_num:10000 Acc@1:72.48%
# Train Epoch: [48/200], lr: 0.051869, Loss: 3.2417
# Test Epoch: [48/200] total_top1:7213.0 total_num:10000 Acc@1:72.13%
# Train Epoch: [49/200], lr: 0.051544, Loss: 3.2126
# Test Epoch: [49/200] total_top1:7340.0 total_num:10000 Acc@1:73.40%
# Train Epoch: [50/200], lr: 0.051213, Loss: 3.2080
# Test Epoch: [50/200] total_top1:7320.0 total_num:10000 Acc@1:73.20%
# Train Epoch: [51/200], lr: 0.050877, Loss: 3.1706
# Test Epoch: [51/200] total_top1:7418.0 total_num:10000 Acc@1:74.18%
# Train Epoch: [52/200], lr: 0.050536, Loss: 3.1680
# Test Epoch: [52/200] total_top1:7372.0 total_num:10000 Acc@1:73.72%
# Train Epoch: [53/200], lr: 0.050190, Loss: 3.1414
# Test Epoch: [53/200] total_top1:7399.0 total_num:10000 Acc@1:73.99%
# Train Epoch: [54/200], lr: 0.049839, Loss: 3.1364
# Test Epoch: [54/200] total_top1:7417.0 total_num:10000 Acc@1:74.17%
# Train Epoch: [55/200], lr: 0.049483, Loss: 3.1391
# Test Epoch: [55/200] total_top1:7382.0 total_num:10000 Acc@1:73.82%
# Train Epoch: [56/200], lr: 0.049123, Loss: 3.1129
# Test Epoch: [56/200] total_top1:7347.0 total_num:10000 Acc@1:73.47%
# Train Epoch: [57/200], lr: 0.048757, Loss: 3.0998
# Test Epoch: [57/200] total_top1:7415.0 total_num:10000 Acc@1:74.15%
# Train Epoch: [58/200], lr: 0.048387, Loss: 3.0998
# Test Epoch: [58/200] total_top1:7373.0 total_num:10000 Acc@1:73.73%
# Train Epoch: [59/200], lr: 0.048013, Loss: 3.0759
# Test Epoch: [59/200] total_top1:7402.0 total_num:10000 Acc@1:74.02%
# Train Epoch: [60/200], lr: 0.047634, Loss: 3.0698
# Test Epoch: [60/200] total_top1:7469.0 total_num:10000 Acc@1:74.69%
# Train Epoch: [61/200], lr: 0.047250, Loss: 3.0624
# Test Epoch: [61/200] total_top1:7515.0 total_num:10000 Acc@1:75.15%
# Train Epoch: [62/200], lr: 0.046863, Loss: 3.0530
# Test Epoch: [62/200] total_top1:7405.0 total_num:10000 Acc@1:74.05%
# Train Epoch: [63/200], lr: 0.046471, Loss: 3.0386
# Test Epoch: [63/200] total_top1:7507.0 total_num:10000 Acc@1:75.07%
# Train Epoch: [64/200], lr: 0.046075, Loss: 3.0090
# Test Epoch: [64/200] total_top1:7496.0 total_num:10000 Acc@1:74.96%
# Train Epoch: [65/200], lr: 0.045675, Loss: 3.0196
# Test Epoch: [65/200] total_top1:7440.0 total_num:10000 Acc@1:74.40%
# Train Epoch: [66/200], lr: 0.045271, Loss: 3.0206
# Test Epoch: [66/200] total_top1:7486.0 total_num:10000 Acc@1:74.86%
# Train Epoch: [67/200], lr: 0.044864, Loss: 2.9796
# Test Epoch: [67/200] total_top1:7559.0 total_num:10000 Acc@1:75.59%
# Train Epoch: [68/200], lr: 0.044453, Loss: 2.9941
# Test Epoch: [68/200] total_top1:7599.0 total_num:10000 Acc@1:75.99%
# Train Epoch: [69/200], lr: 0.044038, Loss: 2.9794
# Test Epoch: [69/200] total_top1:7548.0 total_num:10000 Acc@1:75.48%
# Train Epoch: [70/200], lr: 0.043620, Loss: 2.9617
# Test Epoch: [70/200] total_top1:7455.0 total_num:10000 Acc@1:74.55%
# Train Epoch: [71/200], lr: 0.043198, Loss: 2.9535
# Test Epoch: [71/200] total_top1:7541.0 total_num:10000 Acc@1:75.41%
# Train Epoch: [72/200], lr: 0.042773, Loss: 2.9438
# Test Epoch: [72/200] total_top1:7590.0 total_num:10000 Acc@1:75.90%
# Train Epoch: [73/200], lr: 0.042345, Loss: 2.9218
# Test Epoch: [73/200] total_top1:7589.0 total_num:10000 Acc@1:75.89%
# Train Epoch: [74/200], lr: 0.041914, Loss: 2.9266
# Test Epoch: [74/200] total_top1:7554.0 total_num:10000 Acc@1:75.54%
# Train Epoch: [75/200], lr: 0.041481, Loss: 2.9120
# Test Epoch: [75/200] total_top1:7661.0 total_num:10000 Acc@1:76.61%
# Train Epoch: [76/200], lr: 0.041044, Loss: 2.9073
# Test Epoch: [76/200] total_top1:7585.0 total_num:10000 Acc@1:75.85%
# Train Epoch: [77/200], lr: 0.040604, Loss: 2.8870
# Test Epoch: [77/200] total_top1:7661.0 total_num:10000 Acc@1:76.61%
# Train Epoch: [78/200], lr: 0.040162, Loss: 2.8916
# Test Epoch: [78/200] total_top1:7659.0 total_num:10000 Acc@1:76.59%
# Train Epoch: [79/200], lr: 0.039718, Loss: 2.8762
# Test Epoch: [79/200] total_top1:7657.0 total_num:10000 Acc@1:76.57%
# Train Epoch: [80/200], lr: 0.039271, Loss: 2.8707
# Test Epoch: [80/200] total_top1:7600.0 total_num:10000 Acc@1:76.00%
# Train Epoch: [81/200], lr: 0.038821, Loss: 2.8504
# Test Epoch: [81/200] total_top1:7656.0 total_num:10000 Acc@1:76.56%
# Train Epoch: [82/200], lr: 0.038370, Loss: 2.8459
# Test Epoch: [82/200] total_top1:7669.0 total_num:10000 Acc@1:76.69%
# Train Epoch: [83/200], lr: 0.037916, Loss: 2.8340
# Test Epoch: [83/200] total_top1:7690.0 total_num:10000 Acc@1:76.90%
# Train Epoch: [84/200], lr: 0.037461, Loss: 2.8279
# Test Epoch: [84/200] total_top1:7679.0 total_num:10000 Acc@1:76.79%
# Train Epoch: [85/200], lr: 0.037003, Loss: 2.8065
# Test Epoch: [85/200] total_top1:7742.0 total_num:10000 Acc@1:77.42%
# Train Epoch: [86/200], lr: 0.036544, Loss: 2.8081
# Test Epoch: [86/200] total_top1:7721.0 total_num:10000 Acc@1:77.21%
# Train Epoch: [87/200], lr: 0.036084, Loss: 2.8125
# Test Epoch: [87/200] total_top1:7769.0 total_num:10000 Acc@1:77.69%
# Train Epoch: [88/200], lr: 0.035621, Loss: 2.7921
# Test Epoch: [88/200] total_top1:7706.0 total_num:10000 Acc@1:77.06%
# Train Epoch: [89/200], lr: 0.035158, Loss: 2.7884
# Test Epoch: [89/200] total_top1:7725.0 total_num:10000 Acc@1:77.25%
# Train Epoch: [90/200], lr: 0.034693, Loss: 2.7771
# Test Epoch: [90/200] total_top1:7716.0 total_num:10000 Acc@1:77.16%
# Train Epoch: [91/200], lr: 0.034227, Loss: 2.7779
# Test Epoch: [91/200] total_top1:7820.0 total_num:10000 Acc@1:78.20%
# Train Epoch: [92/200], lr: 0.033760, Loss: 2.7591
# Test Epoch: [92/200] total_top1:7720.0 total_num:10000 Acc@1:77.20%
# Train Epoch: [93/200], lr: 0.033292, Loss: 2.7640
# Test Epoch: [93/200] total_top1:7837.0 total_num:10000 Acc@1:78.37%
# Train Epoch: [94/200], lr: 0.032823, Loss: 2.7795
# Test Epoch: [94/200] total_top1:7766.0 total_num:10000 Acc@1:77.66%
# Train Epoch: [95/200], lr: 0.032354, Loss: 2.7290
# Test Epoch: [95/200] total_top1:7794.0 total_num:10000 Acc@1:77.94%
# Train Epoch: [96/200], lr: 0.031884, Loss: 2.7542
# Test Epoch: [96/200] total_top1:7799.0 total_num:10000 Acc@1:77.99%
# Train Epoch: [97/200], lr: 0.031413, Loss: 2.7398
# Test Epoch: [97/200] total_top1:7874.0 total_num:10000 Acc@1:78.74%
# Train Epoch: [98/200], lr: 0.030942, Loss: 2.7289
# Test Epoch: [98/200] total_top1:7831.0 total_num:10000 Acc@1:78.31%
# Train Epoch: [99/200], lr: 0.030471, Loss: 2.7098
# Test Epoch: [99/200] total_top1:7812.0 total_num:10000 Acc@1:78.12%
# Train Epoch: [100/200], lr: 0.030000, Loss: 2.7207
# Test Epoch: [100/200] total_top1:7887.0 total_num:10000 Acc@1:78.87%
# Train Epoch: [101/200], lr: 0.029529, Loss: 2.7117
# Test Epoch: [101/200] total_top1:7849.0 total_num:10000 Acc@1:78.49%
# Train Epoch: [102/200], lr: 0.029058, Loss: 2.6994
# Test Epoch: [102/200] total_top1:7870.0 total_num:10000 Acc@1:78.70%
# Train Epoch: [103/200], lr: 0.028587, Loss: 2.7050
# Test Epoch: [103/200] total_top1:7941.0 total_num:10000 Acc@1:79.41%
# Train Epoch: [104/200], lr: 0.028116, Loss: 2.7036
# Test Epoch: [104/200] total_top1:7870.0 total_num:10000 Acc@1:78.70%
# Train Epoch: [105/200], lr: 0.027646, Loss: 2.6635
# Test Epoch: [105/200] total_top1:7913.0 total_num:10000 Acc@1:79.13%
# Train Epoch: [106/200], lr: 0.027177, Loss: 2.6554
# Test Epoch: [106/200] total_top1:7964.0 total_num:10000 Acc@1:79.64%
# Train Epoch: [107/200], lr: 0.026708, Loss: 2.6783
# Test Epoch: [107/200] total_top1:7901.0 total_num:10000 Acc@1:79.01%
# Train Epoch: [108/200], lr: 0.026240, Loss: 2.6720
# Test Epoch: [108/200] total_top1:7846.0 total_num:10000 Acc@1:78.46%
# Train Epoch: [109/200], lr: 0.025773, Loss: 2.6556
# Test Epoch: [109/200] total_top1:7924.0 total_num:10000 Acc@1:79.24%
# Train Epoch: [110/200], lr: 0.025307, Loss: 2.6419
# Test Epoch: [110/200] total_top1:7950.0 total_num:10000 Acc@1:79.50%
# Train Epoch: [111/200], lr: 0.024842, Loss: 2.6342
# Test Epoch: [111/200] total_top1:7902.0 total_num:10000 Acc@1:79.02%
# Train Epoch: [112/200], lr: 0.024379, Loss: 2.6423
# Test Epoch: [112/200] total_top1:8000.0 total_num:10000 Acc@1:80.00%
# Train Epoch: [113/200], lr: 0.023916, Loss: 2.6330
# Test Epoch: [113/200] total_top1:7911.0 total_num:10000 Acc@1:79.11%
# Train Epoch: [114/200], lr: 0.023456, Loss: 2.6205
# Test Epoch: [114/200] total_top1:7942.0 total_num:10000 Acc@1:79.42%
# Train Epoch: [115/200], lr: 0.022997, Loss: 2.6224
# Test Epoch: [115/200] total_top1:7952.0 total_num:10000 Acc@1:79.52%
# Train Epoch: [116/200], lr: 0.022539, Loss: 2.6033
# Test Epoch: [116/200] total_top1:7981.0 total_num:10000 Acc@1:79.81%
# Train Epoch: [117/200], lr: 0.022084, Loss: 2.6021
# Test Epoch: [117/200] total_top1:7963.0 total_num:10000 Acc@1:79.63%
# Train Epoch: [118/200], lr: 0.021630, Loss: 2.6094
# Test Epoch: [118/200] total_top1:7978.0 total_num:10000 Acc@1:79.78%
# Train Epoch: [119/200], lr: 0.021179, Loss: 2.5797
# Test Epoch: [119/200] total_top1:7993.0 total_num:10000 Acc@1:79.93%
# Train Epoch: [120/200], lr: 0.020729, Loss: 2.5801
# Test Epoch: [120/200] total_top1:8012.0 total_num:10000 Acc@1:80.12%
# Train Epoch: [121/200], lr: 0.020282, Loss: 2.5847
# Test Epoch: [121/200] total_top1:7988.0 total_num:10000 Acc@1:79.88%
# Train Epoch: [122/200], lr: 0.019838, Loss: 2.5803
# Test Epoch: [122/200] total_top1:7991.0 total_num:10000 Acc@1:79.91%
# Train Epoch: [123/200], lr: 0.019396, Loss: 2.5848
# Test Epoch: [123/200] total_top1:8010.0 total_num:10000 Acc@1:80.10%
# Train Epoch: [124/200], lr: 0.018956, Loss: 2.5579
# Test Epoch: [124/200] total_top1:8043.0 total_num:10000 Acc@1:80.43%
# Train Epoch: [125/200], lr: 0.018519, Loss: 2.5491
# Test Epoch: [125/200] total_top1:7973.0 total_num:10000 Acc@1:79.73%
# Train Epoch: [126/200], lr: 0.018086, Loss: 2.5296
# Test Epoch: [126/200] total_top1:8054.0 total_num:10000 Acc@1:80.54%
# Train Epoch: [127/200], lr: 0.017655, Loss: 2.5442
# Test Epoch: [127/200] total_top1:8041.0 total_num:10000 Acc@1:80.41%
# Train Epoch: [128/200], lr: 0.017227, Loss: 2.5351
# Test Epoch: [128/200] total_top1:8021.0 total_num:10000 Acc@1:80.21%
# Train Epoch: [129/200], lr: 0.016802, Loss: 2.5260
# Test Epoch: [129/200] total_top1:8056.0 total_num:10000 Acc@1:80.56%
# Train Epoch: [130/200], lr: 0.016380, Loss: 2.5257
# Test Epoch: [130/200] total_top1:8051.0 total_num:10000 Acc@1:80.51%
# Train Epoch: [131/200], lr: 0.015962, Loss: 2.5224
# Test Epoch: [131/200] total_top1:8055.0 total_num:10000 Acc@1:80.55%
# Train Epoch: [132/200], lr: 0.015547, Loss: 2.5223
# Test Epoch: [132/200] total_top1:8050.0 total_num:10000 Acc@1:80.50%
# Train Epoch: [133/200], lr: 0.015136, Loss: 2.5179
# Test Epoch: [133/200] total_top1:8042.0 total_num:10000 Acc@1:80.42%
# Train Epoch: [134/200], lr: 0.014729, Loss: 2.5108
# Test Epoch: [134/200] total_top1:8080.0 total_num:10000 Acc@1:80.80%
# Train Epoch: [135/200], lr: 0.014325, Loss: 2.4851
# Test Epoch: [135/200] total_top1:8087.0 total_num:10000 Acc@1:80.87%
# Train Epoch: [136/200], lr: 0.013925, Loss: 2.4894
# Test Epoch: [136/200] total_top1:8050.0 total_num:10000 Acc@1:80.50%
# Train Epoch: [137/200], lr: 0.013529, Loss: 2.4962
# Test Epoch: [137/200] total_top1:8073.0 total_num:10000 Acc@1:80.73%
# Train Epoch: [138/200], lr: 0.013137, Loss: 2.4742
# Test Epoch: [138/200] total_top1:8135.0 total_num:10000 Acc@1:81.35%
# Train Epoch: [139/200], lr: 0.012750, Loss: 2.4823
# Test Epoch: [139/200] total_top1:8094.0 total_num:10000 Acc@1:80.94%
# Train Epoch: [140/200], lr: 0.012366, Loss: 2.4715
# Test Epoch: [140/200] total_top1:8091.0 total_num:10000 Acc@1:80.91%
# Train Epoch: [141/200], lr: 0.011987, Loss: 2.4618
# Test Epoch: [141/200] total_top1:8111.0 total_num:10000 Acc@1:81.11%
# Train Epoch: [142/200], lr: 0.011613, Loss: 2.4591
# Test Epoch: [142/200] total_top1:8134.0 total_num:10000 Acc@1:81.34%
# Train Epoch: [143/200], lr: 0.011243, Loss: 2.4619
# Test Epoch: [143/200] total_top1:8128.0 total_num:10000 Acc@1:81.28%
# Train Epoch: [144/200], lr: 0.010877, Loss: 2.4520
# Test Epoch: [144/200] total_top1:8119.0 total_num:10000 Acc@1:81.19%
# Train Epoch: [145/200], lr: 0.010517, Loss: 2.4601
# Test Epoch: [145/200] total_top1:8125.0 total_num:10000 Acc@1:81.25%
# Train Epoch: [146/200], lr: 0.010161, Loss: 2.4383
# Test Epoch: [146/200] total_top1:8073.0 total_num:10000 Acc@1:80.73%
# Train Epoch: [147/200], lr: 0.009810, Loss: 2.4313
# Test Epoch: [147/200] total_top1:8113.0 total_num:10000 Acc@1:81.13%
# Train Epoch: [148/200], lr: 0.009464, Loss: 2.4268
# Test Epoch: [148/200] total_top1:8155.0 total_num:10000 Acc@1:81.55%
# Train Epoch: [149/200], lr: 0.009123, Loss: 2.4199
# Test Epoch: [149/200] total_top1:8145.0 total_num:10000 Acc@1:81.45%
# Train Epoch: [150/200], lr: 0.008787, Loss: 2.4140
# Test Epoch: [150/200] total_top1:8171.0 total_num:10000 Acc@1:81.71%
# Train Epoch: [151/200], lr: 0.008456, Loss: 2.3995
# Test Epoch: [151/200] total_top1:8125.0 total_num:10000 Acc@1:81.25%
# Train Epoch: [152/200], lr: 0.008131, Loss: 2.4081
# Test Epoch: [152/200] total_top1:8146.0 total_num:10000 Acc@1:81.46%
# Train Epoch: [153/200], lr: 0.007811, Loss: 2.4038
# Test Epoch: [153/200] total_top1:8108.0 total_num:10000 Acc@1:81.08%
# Train Epoch: [154/200], lr: 0.007497, Loss: 2.3979
# Test Epoch: [154/200] total_top1:8179.0 total_num:10000 Acc@1:81.79%
# Train Epoch: [155/200], lr: 0.007188, Loss: 2.3813
# Test Epoch: [155/200] total_top1:8204.0 total_num:10000 Acc@1:82.04%
# Train Epoch: [156/200], lr: 0.006885, Loss: 2.3822
# Test Epoch: [156/200] total_top1:8200.0 total_num:10000 Acc@1:82.00%
# Train Epoch: [157/200], lr: 0.006587, Loss: 2.3819
# Test Epoch: [157/200] total_top1:8192.0 total_num:10000 Acc@1:81.92%
# Train Epoch: [158/200], lr: 0.006295, Loss: 2.3855
# Test Epoch: [158/200] total_top1:8189.0 total_num:10000 Acc@1:81.89%
# Train Epoch: [159/200], lr: 0.006009, Loss: 2.3749
# Test Epoch: [159/200] total_top1:8183.0 total_num:10000 Acc@1:81.83%
# Train Epoch: [160/200], lr: 0.005729, Loss: 2.3776
# Test Epoch: [160/200] total_top1:8198.0 total_num:10000 Acc@1:81.98%
# Train Epoch: [161/200], lr: 0.005456, Loss: 2.3510
# Test Epoch: [161/200] total_top1:8224.0 total_num:10000 Acc@1:82.24%
# Train Epoch: [162/200], lr: 0.005188, Loss: 2.3598
# Test Epoch: [162/200] total_top1:8162.0 total_num:10000 Acc@1:81.62%
# Train Epoch: [163/200], lr: 0.004926, Loss: 2.3429
# Test Epoch: [163/200] total_top1:8220.0 total_num:10000 Acc@1:82.20%
# Train Epoch: [164/200], lr: 0.004670, Loss: 2.3482
# Test Epoch: [164/200] total_top1:8203.0 total_num:10000 Acc@1:82.03%
# Train Epoch: [165/200], lr: 0.004421, Loss: 2.3455
# Test Epoch: [165/200] total_top1:8247.0 total_num:10000 Acc@1:82.47%
# Train Epoch: [166/200], lr: 0.004178, Loss: 2.3391
# Test Epoch: [166/200] total_top1:8222.0 total_num:10000 Acc@1:82.22%
# Train Epoch: [167/200], lr: 0.003941, Loss: 2.3354
# Test Epoch: [167/200] total_top1:8229.0 total_num:10000 Acc@1:82.29%
# Train Epoch: [168/200], lr: 0.003711, Loss: 2.3229
# Test Epoch: [168/200] total_top1:8221.0 total_num:10000 Acc@1:82.21%
# Train Epoch: [169/200], lr: 0.003487, Loss: 2.3278
# Test Epoch: [169/200] total_top1:8239.0 total_num:10000 Acc@1:82.39%
# Train Epoch: [170/200], lr: 0.003270, Loss: 2.3204
# Test Epoch: [170/200] total_top1:8224.0 total_num:10000 Acc@1:82.24%
# Train Epoch: [171/200], lr: 0.003059, Loss: 2.3166
# Test Epoch: [171/200] total_top1:8225.0 total_num:10000 Acc@1:82.25%
# Train Epoch: [172/200], lr: 0.002855, Loss: 2.3145
# Test Epoch: [172/200] total_top1:8248.0 total_num:10000 Acc@1:82.48%
# Train Epoch: [173/200], lr: 0.002658, Loss: 2.3136
# Test Epoch: [173/200] total_top1:8229.0 total_num:10000 Acc@1:82.29%
# Train Epoch: [174/200], lr: 0.002467, Loss: 2.3271
# Test Epoch: [174/200] total_top1:8215.0 total_num:10000 Acc@1:82.15%
# Train Epoch: [175/200], lr: 0.002284, Loss: 2.3003
# Test Epoch: [175/200] total_top1:8228.0 total_num:10000 Acc@1:82.28%
# Train Epoch: [176/200], lr: 0.002107, Loss: 2.2965
# Test Epoch: [176/200] total_top1:8236.0 total_num:10000 Acc@1:82.36%
# Train Epoch: [177/200], lr: 0.001937, Loss: 2.2895
# Test Epoch: [177/200] total_top1:8235.0 total_num:10000 Acc@1:82.35%
# Train Epoch: [178/200], lr: 0.001774, Loss: 2.2874
# Test Epoch: [178/200] total_top1:8228.0 total_num:10000 Acc@1:82.28%
# Train Epoch: [179/200], lr: 0.001617, Loss: 2.2796
# Test Epoch: [179/200] total_top1:8257.0 total_num:10000 Acc@1:82.57%
# Train Epoch: [180/200], lr: 0.001468, Loss: 2.2971
# Test Epoch: [180/200] total_top1:8270.0 total_num:10000 Acc@1:82.70%
# Train Epoch: [181/200], lr: 0.001326, Loss: 2.2965
# Test Epoch: [181/200] total_top1:8251.0 total_num:10000 Acc@1:82.51%
# Train Epoch: [182/200], lr: 0.001191, Loss: 2.2891
# Test Epoch: [182/200] total_top1:8259.0 total_num:10000 Acc@1:82.59%
# Train Epoch: [183/200], lr: 0.001063, Loss: 2.2758
# Test Epoch: [183/200] total_top1:8269.0 total_num:10000 Acc@1:82.69%
# Train Epoch: [184/200], lr: 0.000943, Loss: 2.2913
# Test Epoch: [184/200] total_top1:8274.0 total_num:10000 Acc@1:82.74%
# Train Epoch: [185/200], lr: 0.000829, Loss: 2.2826
# Test Epoch: [185/200] total_top1:8270.0 total_num:10000 Acc@1:82.70%
# Train Epoch: [186/200], lr: 0.000722, Loss: 2.2702
# Test Epoch: [186/200] total_top1:8273.0 total_num:10000 Acc@1:82.73%
# Train Epoch: [187/200], lr: 0.000623, Loss: 2.2770
# Test Epoch: [187/200] total_top1:8264.0 total_num:10000 Acc@1:82.64%
# Train Epoch: [188/200], lr: 0.000531, Loss: 2.2802
# Test Epoch: [188/200] total_top1:8265.0 total_num:10000 Acc@1:82.65%
# Train Epoch: [189/200], lr: 0.000447, Loss: 2.2790
# Test Epoch: [189/200] total_top1:8273.0 total_num:10000 Acc@1:82.73%
# Train Epoch: [190/200], lr: 0.000369, Loss: 2.2626
# Test Epoch: [190/200] total_top1:8267.0 total_num:10000 Acc@1:82.67%
# Train Epoch: [191/200], lr: 0.000299, Loss: 2.2593
# Test Epoch: [191/200] total_top1:8276.0 total_num:10000 Acc@1:82.76%
# Train Epoch: [192/200], lr: 0.000237, Loss: 2.2980
# Test Epoch: [192/200] total_top1:8272.0 total_num:10000 Acc@1:82.72%
# Train Epoch: [193/200], lr: 0.000181, Loss: 2.2587
# Test Epoch: [193/200] total_top1:8274.0 total_num:10000 Acc@1:82.74%
# Train Epoch: [194/200], lr: 0.000133, Loss: 2.2691
# Test Epoch: [194/200] total_top1:8267.0 total_num:10000 Acc@1:82.67%
# Train Epoch: [195/200], lr: 0.000092, Loss: 2.2615
# Test Epoch: [195/200] total_top1:8273.0 total_num:10000 Acc@1:82.73%
# Train Epoch: [196/200], lr: 0.000059, Loss: 2.2787
# Test Epoch: [196/200] total_top1:8278.0 total_num:10000 Acc@1:82.78%
# Train Epoch: [197/200], lr: 0.000033, Loss: 2.2594
# Test Epoch: [197/200] total_top1:8275.0 total_num:10000 Acc@1:82.75%
# Train Epoch: [198/200], lr: 0.000015, Loss: 2.2570
# Test Epoch: [198/200] total_top1:8277.0 total_num:10000 Acc@1:82.77%
# Train Epoch: [199/200], lr: 0.000004, Loss: 2.2615
# Test Epoch: [199/200] total_top1:8273.0 total_num:10000 Acc@1:82.73%
# Train Epoch: [200/200], lr: 0.000000, Loss: 2.2542
# Test Epoch: [200/200] total_top1:8269.0 total_num:10000 Acc@1:82.69%

# %%
import time
while True:
  time.sleep(10)
